# %% [markdown]
# I use my own Google drive space to store the files and folders needed for this project. The code bellow mounts the Google drive, and uses the images uploaded to there before.

# %%
from google.colab import drive

#drive.mount('/content/gdrive')
# !cp /content/Data.zip /content/
# !unzip -q /content/Data.zip -d /content/
# Out:
# cp: '/content/Data.zip' and '/content/Data.zip' are the same file

# %% [markdown]
# The current CUDA version is shown below.

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %% [markdown]
# The code below clones the YOLOv5 from Github, installs all the required dependencies.

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -U -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16117, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 16117 (delta 9), reused 10 (delta 1), pack-reused 16089
# Receiving objects: 100% (16117/16117), 14.85 MiB | 24.48 MiB/s, done.
# Resolving deltas: 100% (11028/11028), done.
# /content/yolov5
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 27.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 34.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 83.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.5/285.5 kB 23.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# In order to start the training, we should run the command below.

# %%
# !python train.py --img-size 640 --batch-size 16 --epochs 50 --data /content/data.yaml --cfg models/yolov5s.yaml --weights yolov5s.pt
# Out:
# 2023-12-28 03:28:19.287388: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-28 03:28:19.287601: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-28 03:28:19.492629: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# The code below saves and downloads the results of training into local cumputer.

# %%
from google.colab import files
# !zip -r /content/yolov5.zip /content/yolov5
files.download("/content/yolov5.zip")
# Out:
#   adding: content/yolov5/ (stored 0%)
#   adding: content/yolov5/benchmarks.py (deflated 69%)
#   adding: content/yolov5/tutorial.ipynb (deflated 74%)
#   adding: content/yolov5/detect.py (deflated 69%)
#   adding: content/yolov5/.dockerignore (deflated 56%)
#   adding: content/yolov5/utils/ (stored 0%)
#   adding: content/yolov5/utils/downloads.py (deflated 62%)
#   adding: content/yolov5/utils/autoanchor.py (deflated 60%)
#   adding: content/yolov5/utils/flask_rest_api/ (stored 0%)
#   adding: content/yolov5/utils/flask_rest_api/example_request.py (deflated 26%)
#   adding: content/yolov5/utils/flask_rest_api/restapi.py (deflated 48%)
#   adding: content/yolov5/utils/flask_rest_api/README.md (deflated 52%)
#   adding: content/yolov5/utils/plots.py (deflated 63%)
#   adding: content/yolov5/utils/activations.py (deflated 68%)
#   adding: content/yolov5/utils/callbacks.py (deflated 68%)
#   adding: content/yolov5/utils/segment/ (stored 0%)
# ...

# %% [markdown]
# After saving and downloading the training results, let us utilize the trained model to detect cats in other pictures.
# Here we test the first database.

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img-size 640 --conf 0.5 --source /content/test/images
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-254-gba63208 Python-3.10.12 torch-2.1.2+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/9 /content/test/images/-DiVf7RUucHwkOLGP3Ay865Lc7Y-SsHF84xZBsM_OFCnceFOcIPU6NPcETILTZW3tar9xDqFGIxSlEG07x61UQ-P_jpg.rf.de534098f39e9dd9e0836fe037a0f984.jpg: 640x640 1 Text, 515.3ms
# ...

# %% [markdown]
# Uploading the second database.

# %%
# !unzip -q /content/Cats.zip -d /content/Cats

# %% [markdown]
# And testing on it.

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --conf 0.5 --source /content/Cats/Cats
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/Cats/Cats, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-254-gba63208 Python-3.10.12 torch-2.1.2+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/6 /content/Cats/Cats/1.jpg: 448x640 (no detections), 335.6ms
# image 2/6 /content/Cats/Cats/2.jpg: 448x640 1 Cat, 357.5ms
# image 3/6 /content/Cats/Cats/3.jpg: 448x640 1 Cat, 337.8ms
# image 4/6 /content/Cats/Cats/4.jpg: 448x640 1 Cat, 305.3ms
# image 5/6 /content/Cats/Cats/5.jpg: 288x640 1 Cat, 220.9ms
# ...
